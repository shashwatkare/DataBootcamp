# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import datetime
from config import consumer_key, consumer_secret, access_token, access_token_secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
from pprint import pprint
tweet_info = api.search("@plotbot5 Analyze:" )
pprint (tweet_info)
# Out:
# {'search_metadata': {'completed_in': 0.036,
#                      'count': 15,
#                      'max_id': 1022942495548874753,
#                      'max_id_str': '1022942495548874753',
#                      'query': '%40plotbot5+Analyze%3A',
#                      'refresh_url': '?since_id=1022942495548874753&q=%40plotbot5%20Analyze%3A&include_entities=1',
#                      'since_id': 0,
#                      'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#                'coordinates': None,
#                'created_at': 'Fri Jul 27 20:31:10 +0000 2018',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [],
#                             'user_mentions': [{'id': 814999527451148288,
#                                                'id_str': '814999527451148288',
#                                                'indices': [0, 9],
#                                                'name': 'PlotBot5',
#                                                'screen_name': 'PlotBot5'},
#                                               {'id': 79923701,
#                                                'id_str': '79923701',
#                                                'indices': [18, 29],
#                                                'name': 'Lin-Manuel Miranda',
#                                                'screen_name': 'Lin_Manuel'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1022942495548874753,
#                'id_str': '1022942495548874753',
#                'in_reply_to_screen_name': 'PlotBot5',
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': 814999527451148288,
#                'in_reply_to_user_id_str': '814999527451148288',
#                'is_quote_status': False,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': None,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com" rel="nofollow">Twitter '
#                          'Web Client</a>',
#                'text': '@PlotBot5 Analyze @Lin_Manuel',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Tue Aug 18 16:48:20 +0000 2009',
#                         'default_profile': True,
#                         'default_profile_image': False,
#                         'description': 'Workaholic, feminist Disney princess. '
#                                        'NPR-dependent commuter, who loves to '
#                                        'cook and wear green shoes.',
#                         'entities': {'description': {'urls': []}},
#                         'favourites_count': 46,
#                         'follow_request_sent': False,
#                         'followers_count': 31,
#                         'following': False,
#                         'friends_count': 95,
#                         'geo_enabled': True,
#                         'has_extended_profile': False,
#                         'id': 66729813,
#                         'id_str': '66729813',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en',
#                         'listed_count': 0,
#                         'location': '',
#                         'name': 'Lauren Creatura',
#                         'notifications': False,
#                         'profile_background_color': 'C0DEED',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': False,
#                         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/66729813/1398388397',
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/459491078056321024/mTQMjuy0_normal.jpeg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/459491078056321024/mTQMjuy0_normal.jpeg',
#                         'profile_link_color': '1DA1F2',
#                         'profile_sidebar_border_color': 'C0DEED',
#                         'profile_sidebar_fill_color': 'DDEEF6',
#                         'profile_text_color': '333333',
#                         'profile_use_background_image': True,
#                         'protected': False,
#                         'screen_name': 'partofthtworld',
#                         'statuses_count': 72,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': None,
#                         'utc_offset': None,
#                         'verified': False}},
#               {'contributors': None,
#                'coordinates': None,
#                'created_at': 'Thu Jul 19 17:36:58 +0000 2018',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [],
#                             'user_mentions': [{'id': 814999527451148288,
#                                                'id_str': '814999527451148288',
#                                                'indices': [0, 9],
#                                                'name': 'PlotBot5',
#                                                'screen_name': 'PlotBot5'},
#                                               {'id': 759251,
#                                                'id_str': '759251',
#                                                'indices': [18, 22],
#                                                'name': 'CNN',
#                                                'screen_name': 'CNN'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1019999553678954496,
#                'id_str': '1019999553678954496',
#                'in_reply_to_screen_name': 'PlotBot5',
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': 814999527451148288,
#                'in_reply_to_user_id_str': '814999527451148288',
#                'is_quote_status': False,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': None,
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com" rel="nofollow">Twitter '
#                          'Web Client</a>',
#                'text': '@PlotBot5 Analyze:@CNN',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Mon Jan 12 22:16:22 +0000 2015',
#                         'default_profile': True,
#                         'default_profile_image': False,
#                         'description': '',
#                         'entities': {'description': {'urls': []}},
#                         'favourites_count': 1,
#                         'follow_request_sent': False,
#                         'followers_count': 3,
#                         'following': False,
#                         'friends_count': 39,
#                         'geo_enabled': False,
#                         'has_extended_profile': False,
#                         'id': 2975401443,
#                         'id_str': '2975401443',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en',
#                         'listed_count': 0,
#                         'location': '',
#                         'name': 'Michelle Fan',
#                         'notifications': False,
#                         'profile_background_color': 'C0DEED',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': False,
#                         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2975401443/1435771710',
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/861399985497178112/vqUyYkSt_normal.jpg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861399985497178112/vqUyYkSt_normal.jpg',
#                         'profile_link_color': '1DA1F2',
#                         'profile_sidebar_border_color': 'C0DEED',
#                         'profile_sidebar_fill_color': 'DDEEF6',
#                         'profile_text_color': '333333',
#                         'profile_use_background_image': True,
#                         'protected': False,
#                         'screen_name': 'whosfan',
#                         'statuses_count': 71,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': None,
#                         'utc_offset': None,
#                         'verified': False}}]}

# %%
command = tweet_info["statuses"][0]["text"]
requesting_user = tweet_info["statuses"][0]["user"]["screen_name"]

# %%
print (command)
# Out:
# @PlotBot5 Analyze @Lin_Manuel

# %%
words = command.split("Analyze")
target_account = words[1].strip()
target_account
# Out:
# '@Lin_Manuel'

# %%
print (target)

# %%
tweets = api.user_timeline()
pprint (tweets)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Jul 19 02:31:20 +0000 2018',
#   'entities': {'hashtags': [{'indices': [28, 41], 'text': 'myfirstTweet'}],
#                'symbols': [],
#                'urls': [],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1019771640987566080,
#   'id_str': '1019771640987566080',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#             'Client</a>',
#   'text': 'Just setting up my Twitter. #myfirstTweet',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#            'created_at': 'Tue Aug 30 12:47:24 +0000 2016',
#            'default_profile': True,
#            'default_profile_image': True,
#            'description': '',
#            'entities': {'description': {'urls': []}},
#            'favourites_count': 4,
#            'follow_request_sent': False,
#            'followers_count': 1,
#            'following': False,
#            'friends_count': 14,
#            'geo_enabled': False,
#            'has_extended_profile': False,
#            'id': 770603829658255361,
#            'id_str': '770603829658255361',
#            'is_translation_enabled': False,
#            'is_translator': False,
#            'lang': 'en',
#            'listed_count': 0,
#            'location': '',
#            'name': 'chuchun huang',
#            'notifications': False,
#            'profile_background_color': 'F5F8FA',
#            'profile_background_image_url': None,
#            'profile_background_image_url_https': None,
#            'profile_background_tile': False,
#            'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#            'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#            'profile_link_color': '1DA1F2',
#            'profile_sidebar_border_color': 'C0DEED',
#            'profile_sidebar_fill_color': 'DDEEF6',
#            'profile_text_color': '333333',
#            'profile_use_background_image': True,
#            'protected': False,
#            'screen_name': 'chuchun_joy',
#            'statuses_count': 1,
#            'time_zone': None,
#            'translator_type': 'none',
#            'url': None,
#            'utc_offset': None,
#            'verified': False}}]
